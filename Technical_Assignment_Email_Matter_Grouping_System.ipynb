# %% [markdown]
# **Stage 1:** data generation, creating email samples.
#
# **Justification for this approach:**
#
# 1.  **Faker Library:** by using the Faker library, I can generate realistic email addresses, names, and timestamps without exposing sensitive data.
#
# 2. **Legal Templates:** the use of predefined legal templates for subjects and body text enables me to generate synthetic emails that closely resemble real legal communications.
#
# 3. **Random Selection & Prefixes:** randomly choosing the matter id for each email ensures a distribution across multiple legal matters. Adding ambiguous or noisy prefixes such as "Re:" and "Fwd:" further simulates real email behavior, where replies and forwarded messages can complicate context recognition.
#
# 4. **True Matter Identifier:** including a true_matter_id for each email allows me to evaluate the performance of our grouping model.

# %%
# !pip install Faker
# Out:
# Requirement already satisfied: Faker in /usr/local/lib/python3.11/dist-packages (37.1.0)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.11/dist-packages (from Faker) (2025.2)

# %%
import pandas as pd
import random
import datetime
from faker import Faker

fake = Faker()

legal_templates = {
    1: {
        'subject': "Litigation Case Update",
        'body_templates': [
            "Recent developments in the litigation have been significant. Please review the attached case documents for updates.",
            "The litigation case has seen new progress. Kindly examine the updated court submissions and legal opinions."
        ]
    },
    2: {
        'subject': "Contract Negotiation Discussion",
        'body_templates': [
            "The contract draft has been revised based on our recent negotiations. Please verify the changes and suggest modifications.",
            "We have updated the contract terms in line with the latest negotiation feedback. Your input on the proposed clauses is appreciated."
        ]
    },
    3: {
        'subject': "Patent Infringement Inquiry",
        'body_templates': [
            "An inquiry regarding potential patent infringement has been received. We need to review the attached documents thoroughly.",
            "Please assess the evidence related to the patent infringement issue. Your expert opinion on the technical details is required."
        ]
    },
    4: {
        'subject': "Property Dispute Resolution",
        'body_templates': [
            "The property dispute has entered a critical phase. Review the attached resolution strategy document and provide your recommendations.",
            "Updates have been made on the property dispute. Please examine the legal analysis and offer your guidance on the next steps."
        ]
    }
}

def generate_legal_email(email_id, matter_id):
    sender = fake.email()
    recipient = fake.email()
    timestamp = fake.date_time_between(start_date='-1y', end_date='now')

    matter_info = legal_templates.get(matter_id, {
        'subject': "General Legal Update",
        'body_templates': ["Please review the attached legal documentation."]
    })
    base_subject = matter_info['subject']
    body_template = random.choice(matter_info['body_templates'])

    prefix = random.choice(["", "Re: ", "Fwd: "])
    subject = prefix + base_subject

    return {
        "email_id": email_id,
        "from": sender,
        "to": recipient,
        "timestamp": timestamp,
        "subject": subject,
        "body": body_template,
        "true_matter_id": matter_id
    }

email_list = []
num_emails = 25

for i in range(num_emails):
    matter_id = random.choice([1, 2, 3, 4])
    email = generate_legal_email(email_id=i+1, matter_id=matter_id)
    email_list.append(email)

for _ in range(3):
    original_email = random.choice(email_list)
    reply_email = {
        "email_id": len(email_list) + 1,
        "from": original_email["to"],
        "to": original_email["from"],
        "timestamp": original_email["timestamp"] + datetime.timedelta(hours=random.randint(1, 24)),
        "subject": ("Re: " + original_email["subject"]) if not original_email["subject"].startswith("Re: ") else original_email["subject"],
        "body": "Following up on our previous discussion, please see my comments and suggested revisions.",
        "true_matter_id": original_email["true_matter_id"]
    }
    email_list.append(reply_email)

df_emails = pd.DataFrame(email_list)
df_emails.sort_values(by="timestamp", inplace=True)

df_emails.head(10)
# Out:
#     email_id                              from                       to  \
# 13        14          jasonhawkins@example.org        zhorn@example.net
# 7          8               janet06@example.net       uayala@example.org
# 1          2             jessica78@example.com        ghall@example.net
# 24        25               ckelley@example.com  cassandra44@example.com
# 9         10  richardsonjacqueline@example.org       vsmith@example.com
# 20        21             michael41@example.org     philip38@example.net
# 10        11              nathan79@example.net    bradley75@example.org
# 0          1     schmidtkristopher@example.net    michael59@example.net
# 21        22      natalieblanchard@example.com    smithadam@example.org
# 14        15        jessicaandrews@example.net   danielbell@example.org
#
#                     timestamp                           subject  \
# 13 2024-04-16 05:22:07.258753       Patent Infringement Inquiry
# 7  2024-05-14 00:21:22.868943        Re: Litigation Case Update
# 1  2024-05-17 21:35:50.688893       Property Dispute Resolution
# 24 2024-05-18 16:51:46.395463       Fwd: Litigation Case Update
# 9  2024-07-25 13:01:46.860135   Re: Patent Infringement Inquiry
# 20 2024-08-19 06:39:01.907658        Re: Litigation Case Update
# 10 2024-09-01 15:53:05.159333   Re: Patent Infringement Inquiry
# 0  2024-09-02 14:12:41.200100   Re: Property Dispute Resolution
# 21 2024-09-03 00:17:17.065691       Fwd: Litigation Case Update
# 14 2024-09-20 16:36:35.286719  Fwd: Patent Infringement Inquiry
#
#                                                  body  true_matter_id
# 13  An inquiry regarding potential patent infringe...               3
# 7   Recent developments in the litigation have bee...               1
# 1   The property dispute has entered a critical ph...               4
# 24  The litigation case has seen new progress. Kin...               1
# 9   An inquiry regarding potential patent infringe...               3
# 20  The litigation case has seen new progress. Kin...               1
# 10  Please assess the evidence related to the pate...               3
# 0   The property dispute has entered a critical ph...               4
# 21  The litigation case has seen new progress. Kin...               1
# 14  Please assess the evidence related to the pate...               3

# %% [markdown]
# **Stage 2:** Mattering Grouping Model
#
# **Semantic Preprocessing of Emails:**
# - I have preprocessed each email by concatenating the subject and body into a single text string.
# - I have also converted the text to lowercase and stripped the extra spaces
# to help in reducing variability due to differences in capitalization or formatting. This standardization improves the consistency of the embeddings generated later.
#
# **Embedding Extraction using Sentence-BERT:**
# - I am employing the all-MiniLM-L6-v2 model from the SentenceTransformer library. This model is well-regarded for its efficiency and ability to capture fine-grained semantic relationships in short texts.
# - By transforming the combined text of each email into dense vector embeddings, I can now effectively compare and group emails based on semantic similarity.
#
# **Clustering with KMeans:**
# - KMeans is chosen due to its simplicity, efficiency, and effectiveness in partitioning vector space into distinct clusters.
#
# **Evaluation Metrics (ARI and NMI):**
# - ARI helps quantify the similarity between our predicted matter assignments and the true matter IDs.
# - NMI measures the amount of information shared between the predicted clusters and the ground truth clusters. It is useful because it is normalized, so it provides a consistent scale even when the number of clusters varies.

# %%
# !pip install scikit-learn sentence-transformers
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (3.4.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.50.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.30.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.1.31)

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score
from sentence_transformers import SentenceTransformer

def preprocess_email(row):
    return f"{row['subject']} {row['body']}".strip().lower()

df_emails['combined_text'] = df_emails.apply(preprocess_email, axis=1)

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')

embeddings = model.encode(df_emails['combined_text'].tolist(), show_progress_bar=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
num_clusters = 4

kmeans = KMeans(n_clusters=num_clusters, random_state=42)
cluster_labels = kmeans.fit_predict(embeddings)

df_emails['predicted_matter_id'] = cluster_labels

# %%
true_labels = df_emails['true_matter_id'].tolist()
ari = adjusted_rand_score(true_labels, cluster_labels)
nmi = normalized_mutual_info_score(true_labels, cluster_labels)

print(f"Adjusted Rand Index (ARI): {ari:.3f}")
print(f"Normalized Mutual Information (NMI): {nmi:.3f}")
# Out:
# Adjusted Rand Index (ARI): 1.000
# Normalized Mutual Information (NMI): 1.000

# %% [markdown]
# **Stage 3:** AI-Powered Matter Summarization
#
# - Google’s Gemini models are designed for high-quality text generation. They have advanced capabilities for understanding and summarizing complex, domain-specific content.
#
# - Prior to summarization, emails are already grouped by their predicted matter. By doing so, I can generate focused summaries for each cluster that are contextually relevant. This grouping leverages our prior work in semantic embedding-based clustering.
#
# - I did some prompt engineering to ensure that the LLM generates a detailed and useful summary.
#
# - Utilizing an open-source client simplifies integration, supports modularity, and makes it easy to replace or update the model in the future if needed.

# %%
# !pip install -q -U google-genai

# %%
from google import genai
from collections import defaultdict

client = genai.Client(api_key="") # Replace with your api-key

def group_emails_by_matter(df, matter_col='predicted_matter_id'):
    matter_groups = defaultdict(list)
    for idx, row in df.iterrows():
        matter_groups[row[matter_col]].append(row.to_dict())
    return matter_groups

def create_summary_prompt(emails):
    emails_sorted = sorted(emails, key=lambda x: x['timestamp'])

    instructions = "This matter involves detailed legal communications regarding a legal case. Please synthesize the essential details into a comprehensive summary."
    recipients = ", ".join(set(email['to'] for email in emails_sorted))
    scope_and_fee = "The scope includes reviewing legal documents and scheduling consultations, with fees applied per consultation."
    ongoing_tasks = "Ongoing tasks include regular updates, periodic legal reviews, and continuous client communications."
    chronology = "\n".join(f"{email['timestamp']} - {email['subject']}" for email in emails_sorted)

    prompt = (
        "Generate a detailed 1-2 page summary for the following matter group. The summary should include:\n"
        "1. Recap of Instructions: " + instructions + "\n"
        "2. Recipient Details: " + recipients + "\n"
        "3. Scope of Work and Fee Information: " + scope_and_fee + "\n"
        "4. Ongoing Tasks: " + ongoing_tasks + "\n"
        "5. Chronology of Events:\n" + chronology + "\n"
        "Provide a comprehensive overview to assist in managing this legal matter."
    )
    return prompt

def generate_summary_with_gemini(prompt_text):
    response = client.models.generate_content(
        model="gemini-2.0-flash",
        contents=[prompt_text]
    )
    return response.text

matter_groups = group_emails_by_matter(df_emails, matter_col='predicted_matter_id')

# %%
if 0 in matter_groups:
    prompt0 = create_summary_prompt(matter_groups[0])
    summary0 = generate_summary_with_gemini(prompt0)
    print("Summary for Matter 0:")
    print("-" * 40)
    print(summary0)
else:
    print("Matter 0 not found in matter_groups.")
# Out:
# Summary for Matter 0:
# ----------------------------------------
# ## Litigation Case Summary: [Insert Case Name/Identifying Number Here]
#
# **1. Recap of Instructions:**
#
# This matter concerns ongoing litigation requiring continuous monitoring and proactive management. The primary directive is to stay informed of all developments within the case and provide regular updates and consultations to involved parties. This involves meticulous review of legal documents, accurate record-keeping of key events, and clear and consistent communication with all recipients listed below. Crucially, the information provided by these legal communications needs to be synthesized into a readily understandable format to facilitate informed decision-making and strategic planning related to the litigation. The overarching goal is to ensure efficient and effective progression of the case while adhering to established budgetary guidelines. The matter requires a proactive approach, anticipating potential issues and proactively addressing them through legal review and strategic consultation.
#
# **2. Recipient Details:**
#
# The following individuals are actively involved in this litigation matter and receive regular updates and communications:
#
# *   **marisahiggins@example.net:** [Assign Role/Affiliation - e.g., Client, Paralegal, Expert Witness] - [Brief Description of Role in Case]
# *   **uayala@example.org:** [Assign Role/Affiliation - e.g., Client, Opposing Counsel] - [Brief Description of Role in Case]
# *   **cassandra44@example.com:** [Assign Role/Affiliation - e.g., Attorney, Legal Assistant] - [Brief Description of Role in Case]
# *   **smithadam@example.org:** [Assign Role/Affiliation - e.g., Client, Expert Witness] - [Brief Description of Role in Case]
# *   **philip38@example.net:** [Assign Role/Affiliation - e.g., Attorney, Paralegal] - [Brief Description of Role in Case]
# *   **acostajennifer@example.org:** [Assign Role/Affiliation - e.g., Client, Paralegal] - [Brief Description of Role in Case]
# *   **loricampbell@example.com:** [Assign Role/Affiliation - e.g., Attorney, Legal Assistant] - [Brief Description of Role in Case]
# *   **emilygregory@example.org:** [Assign Role/Affiliation - e.g., Client, Paralegal] - [Brief Description of Role in Case]
#
# **Note:**  *Assign specific roles and affiliations to each recipient based on your internal records. A brief description of their involvement in the case will help clarify their importance and the information they need to receive.*
#
# **3. Scope of Work and Fee Information:**
#
# The scope of work for this litigation matter encompasses the following key activities:
#
# *   **Document Review:** Comprehensive review and analysis of all incoming and outgoing legal documents related to the case. This includes pleadings, motions, discovery materials, correspondence, and court orders.
# *   **Consultation Scheduling:** Coordinating and scheduling consultations between attorneys, clients, expert witnesses, and other relevant parties. This involves managing calendars, confirming availability, and disseminating meeting details.
# *   **Legal Research:** Conducting legal research to support arguments, identify precedents, and analyze relevant case law.
# *   **Strategy Development:** Assisting in the development and implementation of litigation strategies, in collaboration with senior attorneys.
# *   **Client Communication:** Maintaining regular and clear communication with clients to keep them informed of case progress and answer their questions.
# *   **Case Management:** Overall case management, including tracking deadlines, organizing documents, and managing communication flow.
#
# **Fee Information:**
#
# *   Fees are applied on a per-consultation basis. [**Specify the hourly rate or fixed fee per consultation here**].
# *   Document review, legal research, and other administrative tasks are billed at [**Specify the hourly rate for these tasks here**].
# *   Detailed billing records will be maintained and provided to the client on a [**Specify billing frequency - e.g., monthly**] basis.
#
# **4. Ongoing Tasks:**
#
# The following tasks require continuous attention and effort throughout the duration of this litigation:
#
# *   **Regular Updates:** Providing timely updates to all recipients on the progress of the case, including significant events, deadlines, and potential challenges. Frequency of updates should be determined based on the case activity and client preferences.
# *   **Periodic Legal Reviews:** Conducting periodic legal reviews of the case file to identify potential issues, assess the strength of the legal arguments, and adjust the litigation strategy as needed. These reviews should be documented and shared with senior attorneys.
# *   **Continuous Client Communications:** Maintaining consistent and open communication with the client to ensure they are informed of all developments and have the opportunity to provide input. Proactively address any questions or concerns the client may have.
# *   **Deadline Management:**  Closely monitoring and managing all deadlines, including filing deadlines, discovery deadlines, and hearing dates. Implement a system for tracking deadlines and ensuring timely compliance.
# *   **Document Organization:** Maintaining a well-organized and easily accessible case file, both electronically and physically. This will facilitate efficient retrieval of information and ensure that all documents are readily available when needed.
#
# **5. Chronology of Events:**
#
# The following is a chronological listing of communications related to this litigation case:
#
# *   **2024-05-14 00:21:22.868943 - Re: Litigation Case Update:** Indicates a reply to an existing email thread updating recipients on the litigation case's status. *Action Required: Review original email and this reply to understand the update.*
# *   **2024-05-18 16:51:46.395463 - Fwd: Litigation Case Update:** A forwarded email regarding a litigation case update, suggesting the information is being shared with additional recipients. *Action Required: Review the forwarded email to understand the original update and identify the new recipients.*
# *   **2024-08-19 06:39:01.907658 - Re: Litigation Case Update:** Similar to the first entry, this indicates a reply to an existing email thread with a case update. *Action Required: Review original email and this reply to understand the update.*
# *   **2024-09-03 00:17:17.065691 - Fwd: Litigation Case Update:** Another forwarded email sharing a litigation case update. *Action Required: Review the forwarded email to understand the original update and identify the new recipients.*
# *   **2024-09-22 18:34:22.115094 - Re: Litigation Case Update:**  A reply to an email thread providing another case update. *Action Required: Review original email and this reply to understand the update.*
# *   **2025-01-28 11:50:58.472224 - Litigation Case Update:**  A standalone email providing a case update. This could be a new email thread or a continuation of an existing one. *Action Required: Review the email to understand the update and context.*
# *   **2025-03-08 05:42:40.419492 - Litigation Case Update:**  Another standalone email providing a case update. *Action Required: Review the email to understand the update and context.*
# *   **2025-03-30 07:05:19.817201 - Fwd: Litigation Case Update:** A forwarded email sharing a litigation case update. *Action Required: Review the forwarded email to understand the original update and identify the new recipients.*
#
# **Note:** *This chronology indicates periods of heightened activity (May-September 2024) followed by a relative lull and then resumed activity in 2025. A more detailed review of the emails themselves is necessary to understand the specific developments being communicated during each period.*
#
# **Conclusion:**
#
# This summary provides a comprehensive overview of the litigation matter. Consistent monitoring of ongoing tasks, meticulous document review, and proactive communication with all recipients are crucial for effectively managing this case. The chronological listing of events highlights periods of intense activity and requires further investigation to understand the specifics of each update. Regular review and updates to this summary are essential to ensure it remains accurate and reflects the current status of the litigation.  It's critical to establish a system for organizing and tracking these email communications to efficiently manage the information and ensure all parties are properly informed. Finally, remember to replace bracketed information (e.g., "[Insert Case Name/Identifying Number Here]") with the appropriate details.

# %%
if 1 in matter_groups:
    prompt1 = create_summary_prompt(matter_groups[1])
    summary1 = generate_summary_with_gemini(prompt1)
    print("Summary for Matter 1:")
    print("-" * 40)
    print(summary1)
else:
    print("Matter 1 not found in matter_groups.")
# Out:
# Summary for Matter 1:
# ----------------------------------------
# ## Matter Summary: Contract Negotiation
#
# **1. Recap of Instructions:**
#
# This matter involves the ongoing legal management of a contract negotiation. The core communication revolves around a "Contract Negotiation Discussion," the specifics of which are revealed through email exchanges, including forwards and replies. The objective is to provide legal counsel, review the contract terms, advise on negotiation strategies, and protect the client's interests throughout the negotiation process. The matter also includes the administrative tasks of scheduling consultations, providing regular updates, and conducting periodic legal reviews. The ultimate goal is to achieve a mutually beneficial and legally sound contract agreement.
#
# **2. Recipient Details:**
#
# The following individuals are identified as recipients within the email communications related to this matter:
#
# *   fletchertammy@example.org
# *   thall@example.net
# *   thorntondanielle@example.com
# *   tcollins@example.com
# *   julie81@example.net
# *   fuenteskimberly@example.org
#
# Understanding the roles of these individuals is crucial. They could be opposing counsel, internal stakeholders, subject matter experts, or administrative personnel. Further investigation into their connections to the contract negotiation will be necessary to fully grasp the context of the communications. Identifying their respective roles is critical for effective communication and strategic planning within the matter. For example, knowing if "thorntondanielle@example.com" is in-house counsel for the opposing party allows for a different approach than if she were an internal stakeholder within our client's organization.
#
# **3. Scope of Work and Fee Information:**
#
# The scope of work for this matter encompasses the following key activities:
#
# *   **Document Review:** Thorough review of all legal documents related to the contract negotiation, including the contract itself, amendments, supporting documentation, and communications. This review will focus on identifying potential risks, liabilities, and opportunities for improvement.
# *   **Consultations:** Providing legal consultations to the client regarding the contract terms, negotiation strategies, and potential implications of the agreement.
# *   **Negotiation Strategy Development:** Assisting the client in developing a strategic approach to the negotiation, considering their objectives, risk tolerance, and the other party's position.
# *   **Client Communication:** Maintaining regular communication with the client, providing updates on the progress of the negotiation, and addressing any questions or concerns they may have.
# *   **Periodic Legal Reviews:** Conducting periodic legal reviews of the contract and related documents to ensure compliance with applicable laws and regulations.
#
# **Fee Information:**
#
# Fees for this matter are applied on a **per-consultation basis.** This necessitates meticulous tracking of consultation time, clear communication of fees to the client prior to each consultation, and regular invoicing to ensure timely payment. The hourly rate, minimum consultation time, and any other fee-related specifics must be clearly documented and communicated to all relevant parties. A detailed engagement letter should outline the fee structure to avoid any future misunderstandings.
#
# **4. Ongoing Tasks:**
#
# To ensure the successful management of this matter, the following tasks should be considered as ongoing and actively managed:
#
# *   **Regular Updates:** Providing the client with regular updates on the progress of the contract negotiation, including summaries of key communications, milestones achieved, and any potential roadblocks. This proactive communication helps maintain client confidence and ensures they are fully informed.
# *   **Periodic Legal Reviews:** Conducting periodic legal reviews of the contract and related documents to ensure compliance with applicable laws and regulations. These reviews should be scheduled at regular intervals and triggered by significant events, such as new legislation or changes in the negotiation.
# *   **Continuous Client Communications:** Maintaining open and consistent communication with the client to address their questions, concerns, and any new information that arises during the negotiation process. This includes promptly responding to emails, phone calls, and other inquiries.
# *   **Document Management:** Implementing a robust document management system to organize and track all documents related to the contract negotiation. This system should include version control, access controls, and a clear naming convention to ensure efficient retrieval of information.
# *   **Risk Assessment:** Continuously assessing the risks associated with the contract negotiation and advising the client on strategies to mitigate those risks. This includes identifying potential liabilities, evaluating the enforceability of the contract, and assessing the potential for disputes.
#
# ---
#
# **(Page 2)**
#
# **5. Chronology of Events:**
#
# The following is a chronological listing of the email communications related to the contract negotiation, based on the provided timestamps:
#
# *   **2024-11-11 08:42:47.492958 - Fwd: Contract Negotiation Discussion:** The first recorded communication is a forwarded email thread concerning the contract negotiation. The original content of this forwarded email is crucial to understanding the initial context and direction of the negotiations.
# *   **2024-12-31 02:33:13.358213 - Re: Contract Negotiation Discussion:** A reply to the original "Contract Negotiation Discussion" email thread. This reply likely contains further details or responses to points raised in the initial email.
# *   **2025-02-06 00:00:30.923661 - Fwd: Contract Negotiation Discussion:** Another forwarded email thread, suggesting either a continuation of the previous discussions or a new, related thread. Its contents are critical for tracking the evolution of the negotiation.
# *   **2025-02-14 17:02:58.005253 - Contract Negotiation Discussion:** A potentially new email directly addressing the contract negotiation. The lack of "Fwd:" or "Re:" suggests it may be a fresh initiation of discussion or a summary of previous conversations. The content of this email is essential for determining the current state of the negotiation.
# *   **2025-03-11 04:51:33.427751 - Fwd: Contract Negotiation Discussion:** Another forwarded email related to the ongoing discussions. This indicates continuous communication and information sharing.
# *   **2025-03-11 22:51:33.427751 - Re: Fwd: Contract Negotiation Discussion:** A reply to the most recently forwarded email. This represents the latest point in the timeline and likely contains the most current updates or developments in the contract negotiation.
#
# **Analysis of Chronology:**
#
# The chronology reveals a sustained period of communication regarding the contract negotiation, spanning from November 2024 to March 2025. The frequent use of "Fwd:" and "Re:" indicates ongoing email threads and potentially complex discussions. The lack of subject line variation suggests that the core topic remains focused on the initial "Contract Negotiation Discussion."
#
# **Next Steps:**
#
# 1.  **Review Email Content:** Access and meticulously review the content of all emails listed in the chronology. This is paramount to understanding the specific issues being negotiated, the positions of the parties involved, and any potential areas of conflict.
# 2.  **Identify Key Issues:** Based on the email review, identify the key issues that are central to the contract negotiation. This will help prioritize the scope of work and focus on the most critical areas.
# 3.  **Determine Stakeholder Roles:** Clarify the roles of each recipient listed in the Recipient Details section. Understanding their positions and interests is essential for developing effective negotiation strategies.
# 4.  **Confirm Fee Arrangement:** Verify the specific fee arrangement with the client, including the hourly rate, minimum consultation time, and any other relevant details. This information should be clearly documented in the engagement letter.
# 5.  **Schedule Initial Consultation:** Schedule an initial consultation with the client to discuss the current state of the contract negotiation, their objectives, and their risk tolerance.
# 6.  **Develop Negotiation Strategy:** Based on the information gathered from the email review, stakeholder analysis, and client consultation, develop a comprehensive negotiation strategy that aligns with the client's goals.
#
# This summary provides a foundation for managing this legal matter. Implementing the next steps outlined above will ensure effective representation and a successful outcome for the client. Continued monitoring of communications and proactive management of the ongoing tasks are crucial for navigating the contract negotiation process.

# %%
if 2 in matter_groups:
    prompt2 = create_summary_prompt(matter_groups[2])
    summary2 = generate_summary_with_gemini(prompt2)
    print("Summary for Matter 2:")
    print("-" * 40)
    print(summary2)
else:
    print("Matter 2 not found in matter_groups.")
# Out:
# Summary for Matter 2:
# ----------------------------------------
# ## Legal Matter Summary: Patent Infringement Inquiry
#
# **1. Recap of Instructions:**
#
# This legal matter concerns a potential patent infringement case. The communications indicate an initial inquiry regarding patent infringement, followed by subsequent exchanges likely involving the provision of relevant documents, legal analysis, and discussions regarding potential courses of action. The core issue revolves around determining whether a specific patent is being infringed upon by another party. The legal team is tasked with:
#
# *   **Analyzing the potentially infringed patent:** Understanding the scope and claims of the patent in question.
# *   **Identifying the alleged infringing party and their activities:** Gathering information about the party potentially infringing on the patent and the specific activities that raise concerns.
# *   **Determining whether infringement exists:** Comparing the patent claims with the alleged infringing activities to assess if a violation has occurred.
# *   **Advising the client on potential legal strategies:** Recommending appropriate courses of action based on the legal analysis, including potential negotiation, litigation, or other resolution methods.
# *   **Managing the case:** This encompasses all aspects of case handling, including document review, scheduling consultations, providing updates to the client, and executing the chosen legal strategy.
#
# **2. Recipient Details:**
#
# The following individuals are involved in this matter, likely in varying capacities:
#
# *   bradley75@example.org
# *   mary48@example.com
# *   vsmith@example.com
# *   lfrost@example.org
# *   danielbell@example.org
# *   sierratate@example.com
# *   wvazquez@example.net
# *   zhorn@example.net
# *   samanthalong@example.net
#
# It's crucial to identify the specific role of each recipient within the legal team or as a client representative to streamline communication and delegate tasks effectively. Potential roles could include:
#
# *   **Lead Attorney:** Responsible for overall case strategy and client communication.
# *   **Paralegal/Legal Assistant:** Assists with document management, scheduling, and administrative tasks.
# *   **Patent Attorney/Specialist:** Provides expertise on patent law and infringement analysis.
# *   **Client Representative:** Acts as the primary point of contact for the client.
#
# **3. Scope of Work and Fee Information:**
#
# The defined scope of work includes:
#
# *   **Legal Document Review:** Thorough examination of relevant documents, including the patent in question, any related product literature, and evidence of the allegedly infringing activities.
# *   **Consultations:** Providing legal advice and strategy discussions through scheduled consultations with the client and potentially with other experts.
#
# Fee information is structured around consultations:
#
# *   **Fees Applied Per Consultation:** The specific fee structure should be documented (e.g., hourly rate, flat fee per consultation) to ensure transparent billing practices. It is essential to maintain detailed records of each consultation, including the date, attendees, and key topics discussed. Understanding the applicable rate and the duration of the consultation is critical for accurate billing.
#
# **4. Ongoing Tasks:**
#
# The following ongoing tasks are essential for managing this legal matter:
#
# *   **Regular Updates:** Providing the client with periodic updates on the progress of the case, including significant findings, legal developments, and upcoming tasks. The frequency of updates should be mutually agreed upon and documented.
# *   **Periodic Legal Reviews:** Regularly reviewing the case strategy and legal analysis to ensure it remains aligned with the latest information and legal precedents. This should be done at defined intervals and after any significant developments.
# *   **Continuous Client Communications:** Maintaining open and consistent communication with the client to address their questions, concerns, and any new information they may provide. Prompt responses to client inquiries are crucial for building trust and managing expectations.
#
# **5. Chronology of Events:**
#
# The timeline of communication related to this matter is as follows:
#
# *   **2024-04-16 05:22:07.258753 - Patent Infringement Inquiry:** Initial inquiry signaling the start of the matter.
# *   **2024-07-25 13:01:46.860135 - Re: Patent Infringement Inquiry:** A response to the initial inquiry, likely providing more details or requesting further information. A large gap exists between this date and the initial inquiry.
# *   **2024-09-01 15:53:05.159333 - Re: Patent Infringement Inquiry:** Another response, possibly continuing the discussion or addressing specific questions.
# *   **2024-09-20 16:36:35.286719 - Fwd: Patent Infringement Inquiry:** A forwarded email, suggesting information sharing within the legal team or with the client.
# *   **2024-11-12 20:03:12.559929 - Re: Patent Infringement Inquiry:** A response continuing the discussion or providing updates.
# *   **2024-12-26 23:12:28.521671 - Patent Infringement Inquiry:** Another inquiry related to the patent infringement, potentially signaling new information or a follow-up question.
# *   **2025-01-30 09:06:23.561586 - Fwd: Patent Infringement Inquiry:** A forwarded email, suggesting further information sharing.
# *   **2025-01-31 05:06:23.561586 - Re: Fwd: Patent Infringement Inquiry:** A response to the forwarded email.
# *   **2025-03-04 12:40:18.508613 - Patent Infringement Inquiry:** The most recent communication, indicating the matter is still active.
#
# **Overall Assessment & Recommendations:**
#
# This matter appears to be in the investigative stage of a potential patent infringement case. The chronological events suggest a back-and-forth exchange of information and analysis. The relatively large gaps in communication (e.g., April to July 2024) may indicate periods of intensive document review or client consultation, or potential delays.
#
# **Key recommendations for managing this legal matter effectively:**
#
# *   **Document Organization:** Establish a centralized and organized system for managing all documents related to the case. This includes emails, patent documents, product literature, legal research, and client communications. Utilizing a dedicated case management system is highly recommended.
# *   **Role Clarification:** Clearly define the roles and responsibilities of each individual involved in the matter. This will streamline communication and ensure that tasks are delegated appropriately.
# *   **Next Steps:** Determine the immediate next steps required to advance the case. This may include gathering additional information, conducting further legal research, or scheduling a consultation with the client to discuss potential strategies.
# *   **Client Communication Plan:** Establish a clear client communication plan that outlines the frequency and method of updates. This will help manage client expectations and ensure they remain informed about the progress of the case.
# *   **Budget Tracking:** Maintain careful records of all fees incurred, including those related to consultations. Regularly review the budget to ensure the case remains within financial constraints.
# *   **Statute of Limitations:** Confirm the relevant statute of limitations for patent infringement and ensure that all actions are taken within the prescribed timeframe. This is crucial to protect the client's rights.
#
# By addressing these recommendations, the legal team can effectively manage this patent infringement inquiry and provide the client with the best possible legal representation.

# %%
if 3 in matter_groups:
    prompt3 = create_summary_prompt(matter_groups[3])
    summary3 = generate_summary_with_gemini(prompt3)
    print("Summary for Matter 3:")
    print("-" * 40)
    print(summary3)
else:
    print("Matter 3 not found in matter_groups.")
# Out:
# Summary for Matter 3:
# ----------------------------------------
# ## Matter Group Summary: Property Dispute Resolution
#
# **Date:** October 26, 2023 (Assuming a current date for this summary)
#
# **Subject:** Overview and Management of Property Dispute Resolution Matter
#
# **1. Recap of Instructions:**
#
# This matter involves a property dispute requiring legal review, client consultation, and ongoing management. The core instruction is to actively work towards a resolution of this property dispute by thoroughly analyzing all relevant legal documentation, providing informed legal counsel to the client(s), and maintaining consistent communication throughout the process. This includes:
#
# *   **Document Review:** Complete and ongoing review of all documents related to the property dispute, including but not limited to: deeds, titles, surveys, correspondence between involved parties, and any relevant agreements. This review is essential for understanding the legal basis of the dispute, identifying potential strengths and weaknesses in our client's position, and formulating effective strategies.
# *   **Client Consultation:** Scheduling and conducting consultations with the client(s) to discuss the facts of the case, explain the legal implications of the dispute, explore potential resolution strategies (e.g., negotiation, mediation, litigation), and obtain necessary information for effective representation.
# *   **Strategy Development:** Based on the document review and client consultations, developing a comprehensive legal strategy tailored to achieve the best possible outcome for the client. This strategy should consider various factors, including the legal merits of the case, the client's objectives, and the potential costs and benefits of different approaches.
# *   **Negotiation/Mediation (If Applicable):** Engaging in negotiation or mediation with the opposing party or their legal counsel, with the goal of reaching a mutually agreeable settlement. This may involve drafting and reviewing settlement proposals, participating in mediation sessions, and advocating for the client's interests.
# *   **Litigation (If Necessary):** Preparing and filing all necessary legal documents if litigation becomes necessary to protect the client's rights. This includes drafting pleadings, conducting discovery, preparing for trial, and representing the client in court.
# *   **Ongoing Communication:** Maintaining clear and consistent communication with the client(s), providing regular updates on the progress of the case, and promptly responding to their questions and concerns.
#
# **2. Recipient Details:**
#
# The following individuals are identified as recipients of communications related to this matter:
#
# *   anthonychen@example.com
# *   danielwheeler@example.com
# *   ghall@example.net
# *   nmartin@example.org
# *   michael59@example.net
#
# **Important Note:** It's crucial to determine the roles and responsibilities of each recipient. Are they co-counsel, clients, paralegals, or other parties involved? This information is essential for appropriate communication and workflow management. A communication matrix outlining each recipient's role and required level of information should be developed.
#
# **3. Scope of Work and Fee Information:**
#
# The scope of work encompasses the comprehensive handling of the property dispute, including:
#
# *   Initial consultation and assessment
# *   Document review and analysis
# *   Legal research
# *   Strategy development
# *   Negotiation and settlement discussions
# *   Mediation (if applicable)
# *   Litigation (if necessary), including drafting pleadings, discovery, motion practice, and trial preparation.
#
# **Fee Information:**
#
# Fees are applied on a per-consultation basis. This likely refers to an hourly rate or a flat fee per meeting. It is imperative to:
#
# *   **Confirm the specific fee arrangement:** Clarify the exact rate for consultations and any other applicable fees (e.g., filing fees, expert witness fees).
# *   **Document all consultations:** Keep a detailed record of each consultation, including the date, time, duration, attendees, and topics discussed.
# *   **Track billable hours accurately:** Ensure accurate tracking of all time spent on the matter, including document review, legal research, and communication.
# *   **Provide regular billing statements:** Issue timely and accurate billing statements to the client, clearly outlining the services rendered and the fees incurred.
# *   **Address any billing questions promptly:** Be prepared to answer any questions the client may have about their bill and resolve any disputes fairly and efficiently.
#
# **4. Ongoing Tasks:**
#
# This property dispute resolution matter requires consistent effort and attention. The following tasks are ongoing and vital for proper management:
#
# *   **Regular Updates:** Provide clients with regular updates on the progress of their case, at least bi-weekly, or more frequently if significant events occur. This includes notifying them of important deadlines, developments in the case, and any changes to the legal strategy.
# *   **Periodic Legal Reviews:** Conduct periodic reviews of the case file to ensure that all necessary documents are organized, that all deadlines are met, and that the legal strategy remains appropriate in light of any new developments.
# *   **Continuous Client Communication:** Maintain open and responsive communication with the client, answering their questions promptly, addressing their concerns, and keeping them informed of all important decisions. Proactive communication is key to building trust and managing client expectations.
# *   **Document Management:** Maintain a well-organized and secure system for storing all documents related to the case. This includes both physical and electronic documents. Ensure that all documents are properly labeled and easily accessible. Implement a version control system to track changes to key documents.
# *   **Deadline Monitoring:** Utilize a robust system for tracking all deadlines, including filing deadlines, discovery deadlines, and court dates. Failure to meet deadlines can have serious consequences, so it's essential to have a reliable system in place to ensure that nothing is missed.
# *   **Risk Assessment:** Continuously assess the potential risks and rewards associated with different courses of action. This includes considering the legal merits of the case, the client's objectives, and the potential costs and benefits of settlement versus litigation.
#
# **5. Chronology of Events:**
#
# *   **2024-05-17 21:35:50.688893 - Property Dispute Resolution:** This likely represents the initial creation of the matter file or the first communication related to the property dispute.
# *   **2024-09-02 14:12:41.200100 - Re: Property Dispute Resolution:** A response related to the initial communication. This suggests initial discussions or information gathering.
# *   **2025-02-28 21:07:14.413327 - Fwd: Property Dispute Resolution:** A forwarded email regarding the dispute. This could indicate information sharing within the legal team or to the client(s).
# *   **2025-03-01 09:07:14.413327 - Re: Fwd: Property Dispute Resolution:** A response to the forwarded email, suggesting further discussion or action based on the forwarded information.
# *   **2025-03-11 06:28:36.510760 - Fwd: Property Dispute Resolution:** Another forwarded email, potentially indicating further information sharing or updates to the legal team or client(s).
#
# **Analysis of Chronology:**
#
# The timeline shows an initial engagement in May 2024, followed by relative inactivity until late February/early March 2025. This gap could signify a period of information gathering, negotiation attempts outside of formal communication, or a delay on the client's side. The flurry of activity in late February and early March suggests a renewed focus on the case, possibly due to a deadline approaching, a change in circumstances, or a renewed effort to resolve the dispute.
#
# **Next Steps & Recommendations:**
#
# 1.  **Role Clarification:** Immediately determine the roles and responsibilities of each recipient of communications (anthonychen@example.com, etc.).
# 2.  **Fee Arrangement Confirmation:** Confirm the precise fee arrangement for consultations and other services with the relevant billing personnel or the attorney in charge of the matter.
# 3.  **Document Gathering:** Gather all documents related to the property dispute, including those referenced in the email chronology.
# 4.  **Case File Review:** Conduct a thorough review of the case file to understand the factual background, legal issues, and client objectives.
# 5.  **Client Contact:** Reach out to the client(s) (potentially through the specified emails) to schedule a consultation and discuss the current status of the case.
# 6.  **Strategy Meeting:** Schedule a strategy meeting with the legal team to discuss the case and develop a comprehensive legal strategy.
# 7.  **Establish Communication Protocol:** Implement a clear communication protocol to ensure that all parties are kept informed of the progress of the case.
# 8.  **Deadline Management:** Ensure that all deadlines are accurately tracked and managed.
#
# By implementing these steps, this Property Dispute Resolution matter can be efficiently managed and brought to a successful resolution for the client.

# %% [markdown]
# **Stage 4:** Evaluation.
#
# **Approach 1:** manual comparison of generated summaries to reference matter descriptions
#
# - To assess the quality of generated summaries, I have implemented a manual evaluation approach. This approach allows to qualitatively judge whether each summary met the critical needs for legal matter management mentioned in the read.me.
#
# **Points mentioned in the read.me:**
#
# 1.   **Recap of Instructions:** provided by all summaries.
# 2.   **Recipient Details:** provided by all summaries.
# 3.   **Scope of Work and Fee Information:** provided by all summaries.
# 4.   **Ongoing Tasks:** provided by all summaries.
# 5.   **Chronology of Events:** provided by all summaries.
#
#
# **Qualitative Assessment**
#
# Some key factors that were kept into consideration:
# 1.   **Completeness:** are all the required sections (instructions, recipient details, scope/fee, ongoing tasks, chronology) present?
# 2.   **Accuracy:** is the information correct and reflective of what is present in the raw email content?
# 3.   **Coherence:**  does the summary read as a logically organized?
# 4.   **Relevance:** are only the essential details included, without unnecessary details?
#
# **After a manual check I came to a conclusion that all the summaries were having all these factors in them.**

# %% [markdown]
# **Approach 2:** using a simple scoring function (string overlap)
# - I have choosen Jaccard similarity to quantify how much overlap there is between the words in the generated summary and the words in a reference summary.
#
# **Justification for my choice:**
# - The Jaccard similarity is straightforward to compute and easy to interpret.
#
# - Although it is a basic metric, Jaccard similarity offers a quick quantitative snapshot. It allows us to compare different summarization approaches or monitor improvements with minimal computational overhead, acting as a baseline against which more sophisticated metrics can later be compared.
#
# - The computational cost of calculating Jaccard similarity is low, making it an attractive option for a prototype where multiple summaries are generated and need to be evaluated quickly.

# %%
summaries = {}
for matter_id, emails in matter_groups.items():
    prompt = create_summary_prompt(emails)
    summary = generate_summary_with_gemini(prompt)
    summaries[matter_id] = summary
    print(f"Summary for Matter {matter_id}:\n{'-'*40}\n{summary}\n")
# Out:
# Summary for Matter 2:
# ----------------------------------------
# ## Matter Group Summary: Patent Infringement Inquiry
#
# **1. Recap of Instructions:**
#
# This matter pertains to a potential patent infringement case. The initial communications revolved around an inquiry regarding possible infringement of a client's patent. Subsequent communications represent ongoing investigation, discussion, and analysis related to the alleged infringement. The communications suggest a need for comprehensive legal review to determine the strength of the client's patent, the likelihood of infringement, and the potential strategies for addressing the situation. The goal is to provide the client with informed legal advice and representation related to protecting their patent rights. Key aspects requiring attention include:
#
# *   **Patent Validity:** Assessing the strength and enforceability of the client's patent.
# *   **Infringement Analysis:** Determining if the alleged infringing party's activities actually violate the client's patent claims.
# *   **Legal Strategy:** Developing a course of action, which may include negotiation, litigation, or other appropriate measures, based on the analysis of patent validity and infringement.
# *   **Client Communication:** Maintaining clear and consistent communication with the client throughout the process, ensuring they are informed of all developments and understand the legal implications.
#
# **2. Recipient Details:**
#
# The following individuals are recipients of communications related to this matter. Their roles and responsibilities need to be understood to facilitate effective communication and workflow management.
#
# *   bradley75@example.org
# *   mary48@example.com
# *   vsmith@example.com
# *   lfrost@example.org
# *   danielbell@example.org
# *   sierratate@example.com
# *   wvazquez@example.net
# *   zhorn@example.net
# *   samanthalong@example.net
#
# **Action Item:** *Determine the roles and responsibilities of each recipient (e.g., client, paralegal, associate attorney, expert witness).* Establishing a communication matrix clarifying the purpose and frequency of communication with each recipient is crucial.
#
# **3. Scope of Work and Fee Information:**
#
# The scope of work for this matter currently includes:
#
# *   **Review of Legal Documents:** Comprehensive analysis of all relevant documents, including patent filings, prior art, alleged infringing products or processes, and any related communications.
# *   **Consultations:** Providing legal advice and guidance to the client through scheduled consultations. This includes discussing potential strategies, risks, and costs associated with different courses of action.
#
# Fee information:
#
# *   Fees are applied on a per-consultation basis.
# *   Further legal work (e.g., drafting legal documents, conducting discovery, representing the client in litigation) will require a revised scope of work and associated fee agreement.
#
# **Action Item:** *Confirm the agreed-upon consultation fee and payment schedule with the client. Prepare a formal engagement letter outlining the scope of work, fees, and other relevant terms, if not already completed.*
#
# **4. Ongoing Tasks:**
#
# The following tasks are ongoing and require regular attention:
#
# *   **Regular Updates:** Providing the client with timely updates on the progress of the case, including significant developments, upcoming deadlines, and potential changes in strategy.
# *   **Periodic Legal Reviews:** Conducting regular reviews of the legal landscape to ensure that the chosen strategy remains appropriate and effective. This includes monitoring relevant case law, patent office rulings, and industry trends.
# *   **Continuous Client Communications:** Maintaining open and consistent communication with the client to address their questions, concerns, and needs. This includes promptly responding to emails, phone calls, and other forms of communication.
# *   **Document Management:** Maintaining organized and secure files for all documents related to the matter. Implement a clear naming convention and version control system.
# *   **Legal Research:** Ongoing research into relevant case law, patent regulations, and industry standards to support the legal strategy.
# *   **Internal Team Communication:** Ensuring seamless communication and collaboration within the legal team handling the matter.
#
# **Action Item:** *Establish a system for tracking progress on ongoing tasks and ensuring timely completion. Implement a communication protocol for consistent client updates.*
#
# **5. Chronology of Events:**
#
# Here is a chronological breakdown of the key events in this matter:
#
# *   **2024-04-16 05:22:07.258753 - Patent Infringement Inquiry:** Initial communication initiating the matter, likely from the client expressing concern about potential infringement.
# *   **2024-07-25 13:01:46.860135 - Re: Patent Infringement Inquiry:** Reply to the initial inquiry, potentially outlining the next steps in investigating the matter.
# *   **2024-09-01 15:53:05.159333 - Re: Patent Infringement Inquiry:** Further communication regarding the inquiry, potentially discussing preliminary findings or requests for additional information.
# *   **2024-09-20 16:36:35.286719 - Fwd: Patent Infringement Inquiry:** Forwarded communication, possibly to another attorney or expert for review and analysis.
# *   **2024-11-12 20:03:12.559929 - Re: Patent Infringement Inquiry:** Follow-up communication, potentially discussing the results of initial analysis or exploring potential legal strategies.
# *   **2024-12-26 23:12:28.521671 - Patent Infringement Inquiry:** Further inquiry or update, possibly providing additional information or raising new concerns.
# *   **2025-01-30 09:06:23.561586 - Fwd: Patent Infringement Inquiry:** Another forwarded communication, potentially to an expert witness, patent attorney, or litigation team member.
# *   **2025-01-31 05:06:23.561586 - Re: Fwd: Patent Infringement Inquiry:** Response to the forwarded communication, possibly containing analysis, advice, or a request for further information.
# *   **2025-03-04 12:40:18.508613 - Patent Infringement Inquiry:** Most recent communication, indicating ongoing investigation and client engagement.
#
# **Action Item:** *Analyze the content of each communication to determine the specific issues discussed and the actions taken. Create a detailed timeline of events with summaries of each communication to provide a clear understanding of the matter's history.*
#
# **Overall Action Items and Next Steps:**
#
# 1.  **Define Recipient Roles:** Clarify the roles and responsibilities of each email recipient involved in the matter.
# 2.  **Formalize Engagement:** If not already done, prepare and execute a formal engagement letter with the client outlining the scope of work, fees, and payment terms.
# 3.  **Document Review and Analysis:** Thoroughly review all existing communications and related documents to fully understand the facts and legal issues.
# 4.  **Create Detailed Timeline:** Construct a detailed timeline of events with summaries of each communication.
# 5.  **Patent Validity Assessment:** Conduct a comprehensive assessment of the validity and enforceability of the client's patent.
# 6.  **Infringement Analysis:** Perform a thorough analysis of the alleged infringing party's activities to determine if they infringe on the client's patent claims.
# 7.  **Legal Strategy Development:** Develop a legal strategy based on the analysis of patent validity and infringement, considering the client's goals and risk tolerance.
# 8.  **Client Consultation:** Schedule a consultation with the client to discuss the findings of the analysis and the proposed legal strategy.
# 9.  **Communication Protocol:** Establish a clear communication protocol for consistent client updates and internal team collaboration.
# 10. **Implement Document Management System:** Ensure proper organization and security of all matter-related documents using a consistent naming convention and version control system.
#
# By addressing these action items, the legal team can effectively manage this patent infringement inquiry and provide the client with the best possible legal representation. This summary serves as a foundational document for future actions and should be regularly updated as the matter progresses.
#
#
# Summary for Matter 0:
# ----------------------------------------
# ## Matter Group Summary: Litigation Case Updates & Consultation
#
# **1. Recap of Instructions:**
#
# This matter involves ongoing legal communications pertaining to a specific litigation case. The primary focus is on disseminating and reviewing updates regarding the case's progress and coordinating consultations with relevant parties. Instructions mandate a comprehensive understanding of the case details through review of exchanged documents and continuous client communication. The core activity revolves around the distribution, analysis, and subsequent action based on these "Litigation Case Update" communications. Key objectives include:
#
# *   Staying abreast of all developments in the litigation case.
# *   Ensuring all relevant parties (listed below) are informed of these developments.
# *   Scheduling and coordinating consultations based on the needs identified in the updates.
# *   Maintaining detailed records of communications and consultations.
# *   Providing accurate and timely updates and legal reviews as required.
# *   Managing the client relationship through consistent communication and addressing any queries or concerns.
#
# The case updates appear to be the central communication stream, acting as triggers for document review, consultation scheduling, and further legal analysis. The forwarding of these updates suggests a need for wider distribution and potentially requires careful consideration of privilege and confidentiality depending on the content.
#
# **2. Recipient Details:**
#
# The following individuals are identified as recipients of "Litigation Case Update" communications. Their roles and levels of involvement in the case require further clarification, but can be tentatively categorized for organizational purposes:
#
# *   **Internal Team:** (Assumption: these may be lawyers or paralegals working on the case)
#     *   uayala@example.org
#     *   cassandra44@example.com
#     *   smithadam@example.org
#     *   acostajennifer@example.org
#     *   emilygregory@example.org
# *   **Client:** (Assumption: primary point of contact for the client)
#     *   marisahiggins@example.net
# *   **External Consultants/Co-Counsel:** (Assumption: outside experts or attorneys collaborating on the case)
#     *   philip38@example.net
#     *   loricampbell@example.com
#
# **Action Required:** Ascertain the specific role and level of involvement for each recipient to ensure appropriate and targeted communication. This will inform who needs to be involved in consultations, review documents, and receive different levels of detail in updates.  Specifically, determine who is the primary client contact, and who are the internal team members directly responsible for the case.
#
# **3. Scope of Work and Fee Information:**
#
# The scope of work includes:
#
# *   **Document Review:** Analyzing "Litigation Case Update" communications and associated documentation.
# *   **Consultation Scheduling:** Coordinating and scheduling consultations with recipients as needed based on the updates and case requirements.
# *   **Communication Management:** Disseminating information, responding to inquiries, and managing communication flow among recipients.
# *   **Legal Review:** Providing periodic legal review and analysis of the case based on the updates.
#
# **Fee Information:**
#
# Fees are applied on a per-consultation basis. The specific rate and billing practices require confirmation. It is crucial to track the number and duration of consultations to accurately bill the client.
#
# **Action Required:** Obtain detailed fee structure and billing guidelines for this matter. Implement a system for tracking consultation time and billing.
#
# **4. Ongoing Tasks:**
#
# The following tasks are ongoing and require continuous attention:
#
# *   **Regular Updates:** Monitoring and processing incoming "Litigation Case Update" communications. Distributing these to the appropriate recipients promptly.
# *   **Periodic Legal Reviews:** Conducting regular legal reviews of the case based on the updates, identifying potential risks, opportunities, and strategic considerations.
# *   **Continuous Client Communications:** Maintaining open communication with the client, providing updates on the case's progress, addressing any concerns, and seeking their input on key decisions. This includes summarizing complex legal jargon into easily understandable terms.
# *   **Consultation Management:**  Proactively identifying the need for consultations based on the case updates and scheduling them efficiently. Following up with participants to ensure action items are addressed.
# *   **Document Management:** Maintaining organized and accessible records of all communications, legal documents, and consultation notes. This includes version control and secure storage.
# *   **Risk Assessment:** Continuously assessing the risks associated with the litigation and developing mitigation strategies.
#
# **Action Required:** Establish a workflow for managing updates, scheduling consultations, and maintaining communication with the client. Implement a document management system.
#
# **5. Chronology of Events:**
#
# The following is a chronological list of the recorded "Litigation Case Update" communications:
#
# *   **2024-05-14 00:21:22.868943 - Re: Litigation Case Update**
# *   **2024-05-18 16:51:46.395463 - Fwd: Litigation Case Update**
# *   **2024-08-19 06:39:01.907658 - Re: Litigation Case Update**
# *   **2024-09-03 00:17:17.065691 - Fwd: Litigation Case Update**
# *   **2024-09-22 18:34:22.115094 - Re: Litigation Case Update**
# *   **2025-01-28 11:50:58.472224 - Litigation Case Update**
# *   **2025-03-08 05:42:40.419492 - Litigation Case Update**
# *   **2025-03-30 07:05:19.817201 - Fwd: Litigation Case Update**
#
# **Analysis:**
#
# *   The frequency of updates has varied significantly. There was a period of relative inactivity between September 2024 and January 2025.
# *   The "Re:" and "Fwd:" prefixes indicate replies to existing updates and forwarding of updates, suggesting an ongoing communication thread.
# *   The content of these emails needs to be reviewed to understand the specific developments in the case and to determine any patterns or trends.
# *   A potential gap in communication between updates suggests a need to proactively reach out to the lead attorney to ensure a constant flow of information.
#
# **Action Required:** Review the content of all "Litigation Case Update" communications to understand the context and substance of the case. Create a timeline of key events based on the information contained within these updates.
#
# **Overall Assessment and Recommendations:**
#
# This matter requires a systematic approach to managing the flow of information, coordinating consultations, and maintaining communication with the client. The key recommendations include:
#
# *   **Clarify Roles and Responsibilities:** Determine the specific roles and levels of involvement for each recipient listed above.
# *   **Establish a Communication Protocol:** Define a clear communication protocol for distributing updates, scheduling consultations, and responding to inquiries.
# *   **Implement a Document Management System:** Implement a secure and organized document management system to store all communications and legal documents related to the case.
# *   **Track Time and Expenses:** Implement a system for tracking consultation time and other expenses to ensure accurate billing.
# *   **Conduct a Comprehensive Case Review:** Conduct a comprehensive review of all "Litigation Case Update" communications to gain a thorough understanding of the case and its current status.
# *   **Proactive Communication:** Proactively reach out to the lead attorney to ensure a constant flow of information and to address any gaps in communication.
#
# By implementing these recommendations, we can ensure the effective management of this litigation case and provide the best possible service to our client. This summary should be considered a starting point and requires further investigation into the specifics of the "Litigation Case Update" content.
#
#
# Summary for Matter 3:
# ----------------------------------------
# ## Matter Summary: Property Dispute Resolution
#
# **1. Recap of Instructions:**
#
# This matter group pertains to a property dispute requiring legal review, consultation, and ongoing management. The core issue revolves around a property dispute, as indicated by the consistent subject line across multiple communications. The instructions received involve a need to synthesize detailed legal communications to understand the nuances of the case and to provide accurate and timely advice to the client. This includes understanding the specific legal arguments, evidence presented (or required), and potential outcomes. The purpose of this matter is to efficiently resolve the property dispute in the client's best interest, utilizing legal strategies and communication to achieve a favorable outcome. Further specifics about the nature of the dispute (e.g., boundary dispute, ownership claim, easement issue) are currently unavailable from the information provided and would need to be ascertained from the full content of the emails.
#
# **2. Recipient Details:**
#
# The following individuals are involved in this matter, as indicated by the email addresses identified:
#
# *   **anthonychen@example.com:** Role and responsibilities unknown; needs clarification.
# *   **danielwheeler@example.com:** Role and responsibilities unknown; needs clarification.
# *   **ghall@example.net:** Role and responsibilities unknown; needs clarification.
# *   **nmartin@example.org:** Role and responsibilities unknown; needs clarification.
# *   **michael59@example.net:** Role and responsibilities unknown; needs clarification.
#
# **Action Item:** The role and responsibilities of each recipient need to be determined to understand the communication flow and identify key stakeholders. This will enable efficient information distribution and task delegation. Understanding who is the client, opposing counsel, expert witnesses, paralegals, etc., is crucial.
#
# **3. Scope of Work and Fee Information:**
#
# The scope of work for this matter encompasses:
#
# *   **Reviewing Legal Documents:** Analyzing all documents relevant to the property dispute, including deeds, surveys, contracts, correspondence, and any related legal filings.  This review is crucial to understanding the legal basis of the dispute and identifying potential weaknesses or strengths in the client's position.
# *   **Scheduling Consultations:** Arranging meetings with the client to discuss the case, gather information, provide legal advice, and formulate strategies. This also likely includes consultations with expert witnesses (e.g., surveyors, appraisers) if required.
# *   **Legal Advice and Strategy:**  Based on the document review and client consultations, providing legal advice on the merits of the case, potential legal strategies, and potential outcomes.
# *   **Negotiation and Settlement:** Attempting to resolve the dispute through negotiation with the opposing party. This may involve drafting settlement agreements.
# *   **Litigation (Potential):** Preparing for and conducting litigation if a settlement cannot be reached. This includes drafting pleadings, conducting discovery, and representing the client in court.
#
# **Fee Information:**
#
# Fees are applied on a per-consultation basis.  Further details regarding the exact hourly rate or fixed fee arrangement per consultation are necessary. The overall budget for the matter needs to be clearly defined and communicated to the client, with regular updates on expenses.
#
# **Action Item:** Obtain the specific fee structure for this matter, including consultation rates and any other associated costs (e.g., filing fees, expert witness fees). Clarify the total budget for the client.
#
# **4. Ongoing Tasks:**
#
# *   **Regular Updates:** Providing the client with regular updates on the progress of the case, including significant developments, upcoming deadlines, and changes in strategy.  This builds trust and ensures the client is informed throughout the process.
# *   **Periodic Legal Reviews:** Conducting regular reviews of the case file to ensure all documents are organized, relevant information is readily accessible, and that the legal strategy remains appropriate. This ensures no details are missed.
# *   **Continuous Client Communications:** Maintaining open and consistent communication with the client, responding promptly to inquiries, and ensuring they understand the legal process. This is paramount for client satisfaction.
# *   **Document Management:** Maintaining an organized and easily searchable system for all documents related to the case, including emails, pleadings, discovery materials, and correspondence. A clear document management system is vital for efficient workflow.
# *   **Deadline Management:**  Tracking all deadlines, including court dates, filing deadlines, and discovery deadlines, to ensure compliance and avoid adverse consequences. A reliable deadline tracking system is essential.
# *   **Research:** Conducting ongoing legal research to ensure that the legal strategies employed are up-to-date and comply with all applicable laws and regulations.
#
# **5. Chronology of Events:**
#
# The email communication history suggests the following timeline:
#
# *   **2024-05-17 21:35:50.688893 - Property Dispute Resolution:** Initial communication likely introducing the property dispute. The content of this email is critical for understanding the genesis of the case.
# *   **2024-09-02 14:12:41.200100 - Re: Property Dispute Resolution:** A follow-up communication related to the initial dispute. May contain updated information or requests for action.
# *   **2025-02-28 21:07:14.413327 - Fwd: Property Dispute Resolution:** Forwarded email, potentially from a new recipient or to a wider distribution list. The content of this forwarded email is significant to understand who is now involved and if any new information is presented.
# *   **2025-03-01 09:07:14.413327 - Re: Fwd: Property Dispute Resolution:** A response to the forwarded email, suggesting further discussion or action required.
# *   **2025-03-11 06:28:36.510760 - Fwd: Property Dispute Resolution:** Another forwarded email, indicating potential ongoing communication and involvement of additional parties.
#
# **Action Item:** The content of *all* emails listed in the chronology needs to be reviewed to understand the specific nature of the property dispute, the roles of each recipient, and the current status of the case.
#
# **Overall Assessment and Next Steps:**
#
# This matter involves a property dispute requiring careful legal review and management. The current information is limited, requiring a more in-depth investigation of the email content to ascertain the specifics of the dispute. Key next steps include:
#
# 1.  **Review all email correspondence in the chronology:**  Thoroughly read each email to understand the facts of the case, the legal issues involved, and the roles of each recipient.
# 2.  **Determine the role and responsibilities of each recipient:** Identify who is the client, opposing counsel, potential witnesses, and internal team members.
# 3.  **Obtain the fee structure and budget for the matter:** Clarify the consultation rates and any other associated costs.
# 4.  **Schedule an initial consultation with the client (if not already done):**  Discuss the case in detail, gather all relevant information, and formulate a preliminary legal strategy.
# 5.  **Begin document review and organization:** Create a system for managing and accessing all documents related to the case.
# 6.  **Identify potential deadlines and create a tracking system:** Ensure all deadlines are met to avoid negative consequences.
# 7.  **Formulate a detailed legal strategy based on the document review and client consultation.**
#
# This summary provides a foundation for managing this property dispute matter.  A more comprehensive understanding requires a review of all communications and documents related to the case. Once this review is complete, a more detailed plan of action can be developed.
#
#
# Summary for Matter 1:
# ----------------------------------------
# ## Legal Matter Summary: Contract Negotiation Discussion
#
# **1. Recap of Instructions:**
#
# This matter concerns ongoing legal communication and activities surrounding a contract negotiation. The primary focus is on reviewing and analyzing documents related to the negotiation, advising the client on potential strategies and risks, and facilitating communication between all parties involved. The legal team is responsible for ensuring the client's interests are protected throughout the negotiation process and that the final contract reflects their desired outcomes. The communication logs suggest a complex and potentially protracted negotiation, requiring careful attention to detail and strategic planning. The matter requires monitoring the negotiation's progress, identifying potential roadblocks, and proactively addressing any legal concerns that may arise.
#
# **2. Recipient Details (Internal & External Parties):**
#
# The following individuals are actively involved in this legal matter, based on email addresses observed in communication logs:
#
# *   **fletchertammy@example.org:** Role unclear, requires further investigation. Potentially internal legal team member or client representative.
# *   **thall@example.net:** Role unclear, requires further investigation. Potentially counterparty representative or third-party mediator.
# *   **thorntondanielle@example.com:** Role unclear, requires further investigation. Potentially internal legal team member, client representative, or consultant.
# *   **tcollins@example.com:** Role unclear, requires further investigation. Potentially client representative.
# *   **julie81@example.net:** Role unclear, requires further investigation. Potentially counterparty representative.
# *   **fuenteskimberly@example.org:** Role unclear, requires further investigation. Potentially internal legal team member.
#
# **Crucially, the roles and affiliations of each recipient need to be clarified immediately. This will allow for a better understanding of the communication flow and identification of key stakeholders.** This can be achieved by reviewing the content of the emails themselves and cross-referencing with client information.
#
# **3. Scope of Work and Fee Information:**
#
# The scope of work for this matter includes, but is not necessarily limited to:
#
# *   **Document Review:** Comprehensive review and analysis of all contracts, correspondence, and related documentation pertaining to the contract negotiation. This involves identifying key clauses, potential risks, and areas for improvement.
# *   **Legal Consultation:** Providing legal advice and strategic guidance to the client regarding the negotiation process, potential options, and legal implications of various contract terms.
# *   **Communication & Negotiation Support:** Facilitating communication between the client and the other parties involved in the negotiation, potentially including drafting correspondence, attending meetings, and participating in negotiations on behalf of the client.
# *   **Contract Drafting & Review:** Drafting and/or reviewing contract language to ensure it accurately reflects the client's interests and complies with applicable laws and regulations.
#
# **Fee Information:** Fees are applied on a per-consultation basis. The specific hourly rate or flat fee per consultation should be confirmed with the client agreement or internal billing procedures. Clear documentation of consultation dates, durations, and corresponding fees is essential for accurate billing and client transparency. Additional fees may apply for document review, drafting, and other services outside of scheduled consultations. *A detailed fee schedule should be readily accessible and consistently applied.*
#
# **4. Ongoing Tasks:**
#
# The following tasks are ongoing to effectively manage this legal matter:
#
# *   **Regular Updates:** Providing the client with regular updates on the progress of the contract negotiation, including key developments, potential challenges, and recommended courses of action. Frequency of updates should be determined in consultation with the client.
# *   **Periodic Legal Reviews:** Conducting periodic legal reviews of the contract language and negotiation progress to identify any potential risks or areas for improvement. The frequency of these reviews should be determined based on the complexity of the contract and the progress of the negotiation.
# *   **Continuous Client Communication:** Maintaining open and consistent communication with the client to ensure their needs are being met and that they are fully informed of all relevant developments. This includes promptly responding to client inquiries and providing timely advice and guidance.
# *   **Documentation:** Maintaining a comprehensive and organized record of all communications, documents, and activities related to the contract negotiation. This is crucial for accurate billing, effective case management, and potential future reference.
# *   **Risk Assessment:** Continuously assessing the risks associated with the contract negotiation, including legal risks, financial risks, and reputational risks. Proactively identifying and mitigating these risks is essential to protecting the client's interests.
# *   **Negotiation Strategy Development & Refinement:** Continuously refining the negotiation strategy based on the latest developments and the client's goals. This includes identifying potential leverage points, developing alternative strategies, and anticipating the other party's moves.
# *   **Monitoring Legal and Regulatory Changes:** Staying abreast of any changes in applicable laws and regulations that may impact the contract negotiation. Adapting the negotiation strategy accordingly is crucial to ensuring compliance and protecting the client's interests.
#
# **5. Chronology of Events:**
#
# The communication logs indicate the following timeline of events focused on "Contract Negotiation Discussion":
#
# *   **2024-11-11 08:42:47.492958 - Fwd: Contract Negotiation Discussion:** An email was forwarded, suggesting an initial stage of information dissemination or introduction to the negotiation.
# *   **2024-12-31 02:33:13.358213 - Re: Contract Negotiation Discussion:** A reply to the initial discussion, indicating active engagement and potentially addressing specific points or questions. The late hour suggests urgency or a tight deadline.
# *   **2025-02-06 00:00:30.923661 - Fwd: Contract Negotiation Discussion:** Another forwarded email, possibly containing updated information, revised contract drafts, or counter-proposals. Again, the late hour is noteworthy.
# *   **2025-02-14 17:02:58.005253 - Contract Negotiation Discussion:** A new email thread or a continuation of the previous discussion. The subject line suggests an ongoing and possibly complex negotiation.
# *   **2025-03-11 04:51:33.427751 - Fwd: Contract Negotiation Discussion:** Further forwarding of information, potentially highlighting specific points or concerns.
# *   **2025-03-11 22:51:33.427751 - Re: Fwd: Contract Negotiation Discussion:** A reply to the forwarded email, suggesting a continuation of the discussion and potentially addressing specific issues raised in the forwarded message.
#
# **Analysis of Chronology:** The chronology suggests a protracted and potentially complex negotiation spanning several months. The repeated forwarding and replies indicate a dynamic exchange of information and a possible lack of consensus on key issues. The late-night communications on multiple occasions suggest high-pressure circumstances or demanding deadlines. *Reviewing the actual email content is crucial to understanding the specific issues being negotiated and the progress being made.*
#
# **Overall Assessment and Recommendations:**
#
# This legal matter involves a contract negotiation that appears to be ongoing and complex. To effectively manage this matter, the following actions are recommended:
#
# *   **Identify and Clarify Roles:** Immediately determine the roles and affiliations of all email recipients to understand the communication flow and identify key stakeholders.
# *   **Review Email Content:** Conduct a thorough review of all email communications to understand the specific issues being negotiated, the progress being made, and any potential roadblocks.
# *   **Client Consultation:** Schedule a consultation with the client to discuss their goals, concerns, and desired outcomes for the contract negotiation.
# *   **Document Review and Analysis:** Conduct a comprehensive review and analysis of all relevant contracts and related documentation.
# *   **Develop Negotiation Strategy:** Develop a clear and effective negotiation strategy that aligns with the client's goals and protects their interests.
# *   **Monitor and Document Progress:** Continuously monitor the progress of the negotiation and document all activities, communications, and agreements.
# *   **Risk Management:** Identify and mitigate any potential risks associated with the contract negotiation.
# *   **Billing Accuracy:** Ensure accurate and transparent billing practices, adhering to the agreed-upon fee structure.
#
# By taking these steps, the legal team can effectively manage this contract negotiation, protect the client's interests, and achieve a favorable outcome.

# %%
def jaccard_similarity(text1, text2):
    words1 = set(text1.lower().split())
    words2 = set(text2.lower().split())
    intersection = words1.intersection(words2)
    union = words1.union(words2)
    return len(intersection) / len(union) if union else 0

# %%
reference_summaries = {
    0: "Reference summary for Matter 0: A detailed overview covering instructions, recipients, scope of work, ongoing tasks, and chronology of events.",
    1: "Reference summary for Matter 1: A comprehensive summary with key legal instructions, contact details, fee structure, and a timeline of events.",
    2: "Reference summary for Matter 2: An in-depth summary including essential instructions, recipient details, work scope, fee information, ongoing tasks, and chronology.",
    3: "Reference summary for Matter 3: A detailed report providing a recap of instructions, recipient list, scope and fee details, ongoing updates, and a chronological timeline."
}

for matter_id, generated_summary in summaries.items():
    ref_summary = reference_summaries.get(matter_id, "")
    if ref_summary:
        score = jaccard_similarity(generated_summary, ref_summary)
        print(f"Matter {matter_id} - Jaccard Similarity Score: {score:.3f}")
    else:
        print(f"Matter {matter_id} - No reference summary available for evaluation.")
# Out:
# Matter 2 - Jaccard Similarity Score: 0.021
# Matter 0 - Jaccard Similarity Score: 0.022
# Matter 3 - Jaccard Similarity Score: 0.028
# Matter 1 - Jaccard Similarity Score: 0.022
